# %% [markdown]
# ***API CALLS:***

# %%
import json
import requests
import pandas as pd

#You can check how many queries you already sent and how your limits are defined by calling https://api.meteomatics.com/user_stats
#The same in a machine readable format: https://api.meteomatics.com/user_stats_json

# %% [markdown]
# ***Turbine1***

# %%
API_CALL = ('https://student_hulse:st7W5y9QSw@api.meteomatics.com/2023-03-17T12:00:00.000+01:00--2023-03-22T12:00:00.000+01:00:PT6H/wind_speed_100m:ms,wind_dir_100m:d/41.686371,-8.996471/json?model=mix')

response = requests.get(API_CALL)

# %%
# Parse the JSON response
data = json.loads(response.content)
data
# Out:
# {'version': '3.0',
#  'user': 'student_hulse',
#  'dateGenerated': '2023-03-12T15:58:28Z',
#  'status': 'OK',
#  'data': [{'parameter': 'wind_speed_100m:ms',
#    'coordinates': [{'lat': 41.686371,
#      'lon': -8.996471,
#      'dates': [{'date': '2023-03-17T11:00:00Z', 'value': 10.1},
#       {'date': '2023-03-17T17:00:00Z', 'value': 8.7},
#       {'date': '2023-03-17T23:00:00Z', 'value': 8.3},
#       {'date': '2023-03-18T05:00:00Z', 'value': 8.2},
#       {'date': '2023-03-18T11:00:00Z', 'value': 13.7},
#       {'date': '2023-03-18T17:00:00Z', 'value': 14.6},
#       {'date': '2023-03-18T23:00:00Z', 'value': 11.4},
#       {'date': '2023-03-19T05:00:00Z', 'value': 9.4},
#       {'date': '2023-03-19T11:00:00Z', 'value': 7.0},
#       {'date': '2023-03-19T17:00:00Z', 'value': 4.8},
#       {'date': '2023-03-19T23:00:00Z', 'value': 1.6},
#       {'date': '2023-03-20T05:00:00Z', 'value': 3.8},
#       {'date': '2023-03-20T11:00:00Z', 'value': 7.8},
# ...

# %%
my_data = {
    "Date": ["2023-03-17 11:00:00", "2023-03-17 17:00:00", "2023-03-17 23:00:00", "2023-03-18 05:00:00", "2023-18-10 11:00:00", "2023-03-18 17:00:00", "2023-03-18 23:00:00", "2023-03-19 05:00:00", "2023-03-19 11:00:00", "2023-03-19 17:00:00", "2023-03-19 23:00:00", "2023-03-20 05:00:00", "2023-03-20 11:00:00", "2023-03-20 17:00:00", "2023-03-20 23:00:00", "2023-03-21 05:00:00", "2023-03-21 11:00:00", "2023-03-21 17:00:00", "2023-03-21 23:00:00", "2023-03-22 05:00:00", "2023-03-22 11:00:00"],
    "wind Speed (ms)": [10.1, 8.7, 8.3, 8.2, 13.7, 14.6, 11.4, 9.4, 7.0, 4.8, 1.6, 3.8, 7.8, 8.4, 9.4, 8.0, 5.7, 4.6, 5.1, 4.2, 3.4],
    "Wind Direction (d)": [236.6, 239.3, 243.3, 240.1, 212.5, 315.4, 321.6, 322.9, 326.0, 327.9, 313.9, 151.8, 176.7, 229.0, 253.5, 308.2, 300.1, 272.4, 239.7, 307.7, 329.0]
}

# %%
df = pd.DataFrame(my_data)
df.rename(columns={'Date':'Time', 'wind Speed (ms)':'WindSpeed (m/s)', 'Wind Direction (d)':'Wind Direction (°)'}, inplace=True)
df.set_index('Time', inplace=True)
df['WindSpeed (m/s)'] = df['WindSpeed (m/s)'].astype(int)
df['Wind Direction (°)'] = df['Wind Direction (°)'].astype(int)
df
# Out:
#                      WindSpeed (m/s)  Wind Direction (°)
# Time
# 2023-03-17 11:00:00               10                 236
# 2023-03-17 17:00:00                8                 239
# 2023-03-17 23:00:00                8                 243
# 2023-03-18 05:00:00                8                 240
# 2023-18-10 11:00:00               13                 212
# 2023-03-18 17:00:00               14                 315
# 2023-03-18 23:00:00               11                 321
# 2023-03-19 05:00:00                9                 322
# 2023-03-19 11:00:00                7                 326
# 2023-03-19 17:00:00                4                 327
# 2023-03-19 23:00:00                1                 313
# 2023-03-20 05:00:00                3                 151
# 2023-03-20 11:00:00                7                 176
# 2023-03-20 17:00:00                8                 229
# 2023-03-20 23:00:00                9                 253
# ...

# %%
#export so that you can add to model to get tubine predicted power:
df.to_csv('WindFloat_Atlantic_Turbine_Conditions.csv')

# %% [markdown]
# ***Turbine2***

# %%
API_CALL2 = ('https://student_hulse:st7W5y9QSw@api.meteomatics.com/2023-03-17T12:00:00.000+01:00--2023-03-22T12:00:00.000+01:00:PT6H/wind_speed_100m:ms,wind_dir_100m:d/40.415956,4.220416/json?model=mix')

response2 = requests.get(API_CALL2)

# %%
# Parse the JSON response
data2 = json.loads(response2.content)
data2
# Out:
# {'version': '3.0',
#  'user': 'student_hulse',
#  'dateGenerated': '2023-03-12T16:07:08Z',
#  'status': 'OK',
#  'data': [{'parameter': 'wind_speed_100m:ms',
#    'coordinates': [{'lat': 40.415956,
#      'lon': 4.220416,
#      'dates': [{'date': '2023-03-17T11:00:00Z', 'value': 11.6},
#       {'date': '2023-03-17T17:00:00Z', 'value': 9.7},
#       {'date': '2023-03-17T23:00:00Z', 'value': 5.2},
#       {'date': '2023-03-18T05:00:00Z', 'value': 6.4},
#       {'date': '2023-03-18T11:00:00Z', 'value': 4.3},
#       {'date': '2023-03-18T17:00:00Z', 'value': 8.4},
#       {'date': '2023-03-18T23:00:00Z', 'value': 8.7},
#       {'date': '2023-03-19T05:00:00Z', 'value': 8.8},
#       {'date': '2023-03-19T11:00:00Z', 'value': 8.4},
#       {'date': '2023-03-19T17:00:00Z', 'value': 17.0},
#       {'date': '2023-03-19T23:00:00Z', 'value': 17.9},
#       {'date': '2023-03-20T05:00:00Z', 'value': 14.9},
#       {'date': '2023-03-20T11:00:00Z', 'value': 13.8},
# ...

# %%
my_data2 = {
    "Date": ["2023-03-17 11:00:00", "2023-03-17 17:00:00", "2023-03-17 23:00:00", "2023-03-18 05:00:00", "2023-18-10 11:00:00", "2023-03-18 17:00:00", "2023-03-18 23:00:00", "2023-03-19 05:00:00", "2023-03-19 11:00:00", "2023-03-19 17:00:00", "2023-03-19 23:00:00", "2023-03-20 05:00:00", "2023-03-20 11:00:00", "2023-03-20 17:00:00", "2023-03-20 23:00:00", "2023-03-21 05:00:00", "2023-03-21 11:00:00", "2023-03-21 17:00:00", "2023-03-21 23:00:00", "2023-03-22 05:00:00", "2023-03-22 11:00:00"],
    "wind Speed (ms)": [11.6, 9.7, 5.2, 6.4, 4.3, 8.4, 8.7, 8.8, 8.4, 17.0, 17.9, 14.9, 13.8, 9.6, 5.4, 3.6, 3.5, 6.1, 2.3, 8.4, 8.7],
    "Wind Direction (d)": [127.3, 137.1, 210.0, 259.9, 216.6, 188.3, 193.4, 224.9, 279.4, 342.0, 350.8, 0.1, 350.1, 0.8, 352.5, 311.0, 212.7, 200.6, 145.3, 178.1, 190.3]
}

# %%
df2 = pd.DataFrame(my_data2)
df2.rename(columns={'Date':'Time', 'wind Speed (ms)':'WindSpeed (m/s)', 'Wind Direction (d)':'Wind Direction (°)'}, inplace=True)
df2.set_index('Time', inplace=True)
df2['WindSpeed (m/s)'] = df2['WindSpeed (m/s)'].astype(int)
df2['Wind Direction (°)'] = df2['Wind Direction (°)'].astype(int)
df2
# Out:
#                      WindSpeed (m/s)  Wind Direction (°)
# Time
# 2023-03-17 11:00:00               11                 127
# 2023-03-17 17:00:00                9                 137
# 2023-03-17 23:00:00                5                 210
# 2023-03-18 05:00:00                6                 259
# 2023-18-10 11:00:00                4                 216
# 2023-03-18 17:00:00                8                 188
# 2023-03-18 23:00:00                8                 193
# 2023-03-19 05:00:00                8                 224
# 2023-03-19 11:00:00                8                 279
# 2023-03-19 17:00:00               17                 342
# 2023-03-19 23:00:00               17                 350
# 2023-03-20 05:00:00               14                   0
# 2023-03-20 11:00:00               13                 350
# 2023-03-20 17:00:00                9                   0
# 2023-03-20 23:00:00                5                 352
# ...

# %%
#export so that you can add to model to get tubine predicted power:
df2.to_csv('Menorca_Wind_Turbine_Conditions.csv')

# %% [markdown]
# ***Turbine3:***

# %%
API_CALL3 = ('https://student_hulse:st7W5y9QSw@api.meteomatics.com/2023-03-17T12:00:00.000+01:00--2023-03-22T12:00:00.000+01:00:PT6H/wind_speed_100m:ms,wind_dir_100m:d/44.585227,-7.876871/json?model=mix')

response3 = requests.get(API_CALL3)

# %%
# Parse the JSON response
data3 = json.loads(response3.content)
data3
# Out:
# {'version': '3.0',
#  'user': 'student_hulse',
#  'dateGenerated': '2023-03-13T11:43:12Z',
#  'status': 'OK',
#  'data': [{'parameter': 'wind_speed_100m:ms',
#    'coordinates': [{'lat': 44.585227,
#      'lon': -7.876871,
#      'dates': [{'date': '2023-03-17T11:00:00Z', 'value': 13.7},
#       {'date': '2023-03-17T17:00:00Z', 'value': 11.1},
#       {'date': '2023-03-17T23:00:00Z', 'value': 11.5},
#       {'date': '2023-03-18T05:00:00Z', 'value': 12.5},
#       {'date': '2023-03-18T11:00:00Z', 'value': 11.8},
#       {'date': '2023-03-18T17:00:00Z', 'value': 14.3},
#       {'date': '2023-03-18T23:00:00Z', 'value': 15.9},
#       {'date': '2023-03-19T05:00:00Z', 'value': 13.5},
#       {'date': '2023-03-19T11:00:00Z', 'value': 13.7},
#       {'date': '2023-03-19T17:00:00Z', 'value': 18.2},
#       {'date': '2023-03-19T23:00:00Z', 'value': 19.1},
#       {'date': '2023-03-20T05:00:00Z', 'value': 16.6},
#       {'date': '2023-03-20T11:00:00Z', 'value': 15.2},
# ...

# %%
my_data3 = {
    "Date": ["2023-03-17 11:00:00", "2023-03-17 17:00:00", "2023-03-17 23:00:00", "2023-03-18 05:00:00", "2023-18-10 11:00:00", "2023-03-18 17:00:00", "2023-03-18 23:00:00", "2023-03-19 05:00:00", "2023-03-19 11:00:00", "2023-03-19 17:00:00", "2023-03-19 23:00:00", "2023-03-20 05:00:00", "2023-03-20 11:00:00", "2023-03-20 17:00:00", "2023-03-20 23:00:00", "2023-03-21 05:00:00", "2023-03-21 11:00:00", "2023-03-21 17:00:00", "2023-03-21 23:00:00", "2023-03-22 05:00:00", "2023-03-22 11:00:00"],
    "wind Speed (ms)": [13.7, 11.1, 11.5, 12.5, 11.8, 14.3, 15.9, 13.5, 13.7, 18.2, 19.1, 16.6, 15.2, 15.0, 17.2, 16.5, 14.2, 12.7, 14.1, 19.4, 15.8],
    "Wind Direction (d)": [222.9, 253.5, 257.7, 261.4, 256.3, 226.2, 242.3, 251.1, 239.8, 230.9, 228.6, 244.4, 241.6, 238.0, 239.5, 273.6, 276.1, 272.6, 241.0, 262.2, 287.7]
}

# %%
df3 = pd.DataFrame(my_data3)
df3.rename(columns={'Date':'Time', 'wind Speed (ms)':'WindSpeed (m/s)', 'Wind Direction (d)':'Wind Direction (°)'}, inplace=True)
df3.set_index('Time', inplace=True)
df3['WindSpeed (m/s)'] = df3['WindSpeed (m/s)'].astype(int)
df3['Wind Direction (°)'] = df3['Wind Direction (°)'].astype(int)
df3
# Out:
#                      WindSpeed (m/s)  Wind Direction (°)
# Time
# 2023-03-17 11:00:00               13                 222
# 2023-03-17 17:00:00               11                 253
# 2023-03-17 23:00:00               11                 257
# 2023-03-18 05:00:00               12                 261
# 2023-18-10 11:00:00               11                 256
# 2023-03-18 17:00:00               14                 226
# 2023-03-18 23:00:00               15                 242
# 2023-03-19 05:00:00               13                 251
# 2023-03-19 11:00:00               13                 239
# 2023-03-19 17:00:00               18                 230
# 2023-03-19 23:00:00               19                 228
# 2023-03-20 05:00:00               16                 244
# 2023-03-20 11:00:00               15                 241
# 2023-03-20 17:00:00               15                 238
# 2023-03-20 23:00:00               17                 239
# ...

# %%
#export so that you can add to model to get tubine predicted power:
df3.to_csv('Galicia_Wind_Turbine_Conditions.csv')
